# %%
import heapq
import networkx as nx
import matplotlib.pyplot as plt

# Fungsi Dijkstra
def dijkstra_with_paths(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    previous = {node: None for node in graph}
    queue = [(0, start)]

    while queue:
        current_distance, current_node = heapq.heappop(queue)

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(queue, (distance, neighbor))

    return distances, previous

# Fungsi untuk mendapatkan jalur terpendek
def get_path(previous, start, end):
    path = []
    target = end
    while target is not None:
        path.insert(0, target)
        target = previous[target]
    return path

# Fungsi visualisasi graf - Circular Layout
def visualize_graph(graph, path=None):
    G = nx.DiGraph()

    for node in graph:
        for neighbor, weight in graph[node].items():
            G.add_edge(node, neighbor, weight=weight)

    pos = nx.circular_layout(G)
    edge_labels = nx.get_edge_attributes(G, 'weight')

    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000, font_weight='bold', arrows=True)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    if path and len(path) > 1:
        path_edges = list(zip(path, path[1:]))
        nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=3)

    plt.title("Visualisasi Graf (Circular Layout)")
    plt.axis('off')
    plt.show()

# Data graf (modifikasi: siklus + simpul baru)
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'C': 1, 'D': 5, 'A': 7},  # Siklus B → A
    'C': {'D': 8, 'E': 10},
    'D': {'E': 2, 'Z': 6, 'B': 3},  # Siklus D → B
    'E': {'Z': 3},
    'Z': {},
    'X': {'A': 7, 'D': 3}  # Simpul baru X
}

# Jalankan algoritma Dijkstra
start_node = 'X'
end_node = 'Z'
distances, previous = dijkstra_with_paths(graph, start_node)

# Ambil jalur terpendek
shortest_path = get_path(previous, start_node, end_node)
print(f"Jarak dari {start_node} ke {end_node}: {distances[end_node]}")
print(f"Jalur: {'→'.join(shortest_path)}")

# Visualisasikan graf
visualize_graph(graph, path=shortest_path)
# Out:
# Jarak dari X ke Z: 8
# Jalur: X→D→E→Z

# %%
import heapq
import networkx as nx
import matplotlib.pyplot as plt

# Fungsi Dijkstra
def dijkstra_with_paths(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    previous = {node: None for node in graph}
    queue = [(0, start)]

    while queue:
        current_distance, current_node = heapq.heappop(queue)

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(queue, (distance, neighbor))

    return distances, previous

# Fungsi untuk mendapatkan jalur terpendek
def get_path(previous, start, end):
    path = []
    target = end
    while target is not None:
        path.insert(0, target)
        target = previous[target]
    return path

# Fungsi visualisasi graf - Kamada-Kawai Layout
def visualize_graph(graph, path=None):
    G = nx.DiGraph()

    for node in graph:
        for neighbor, weight in graph[node].items():
            G.add_edge(node, neighbor, weight=weight)

    pos = nx.kamada_kawai_layout(G)
    edge_labels = nx.get_edge_attributes(G, 'weight')

    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000, font_weight='bold', arrows=True)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    if path and len(path) > 1:
        path_edges = list(zip(path, path[1:]))
        nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=3)

    plt.title("Visualisasi Graf (Kamada-Kawai Layout)")
    plt.axis('off')
    plt.show()

# Data graf (modifikasi: siklus + simpul baru)
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'C': 1, 'D': 5, 'A': 7},  # Siklus B → A
    'C': {'D': 8, 'E': 10},
    'D': {'E': 2, 'Z': 6, 'B': 3},  # Siklus D → B
    'E': {'Z': 3},
    'Z': {},
    'X': {'A': 7, 'D': 3}  # Simpul baru X
}

# Jalankan algoritma Dijkstra
start_node = 'X'
end_node = 'Z'
distances, previous = dijkstra_with_paths(graph, start_node)

# Ambil jalur terpendek
shortest_path = get_path(previous, start_node, end_node)
print(f"Jarak dari {start_node} ke {end_node}: {distances[end_node]}")
print(f"Jalur: {'→'.join(shortest_path)}")

# Visualisasikan graf
visualize_graph(graph, path=shortest_path)
# Out:
# Jarak dari X ke Z: 8
# Jalur: X→D→E→Z
